# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import functions.get_var as gv
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sim = 'dxdz10_sfactor0'
pcnt3 = 30000
startavg = 1
endavg = 6
wbase = 100

tke_budget_flag = True
derivatives_flag = True
PCON_flag = False
PCON_TEMP_flag = False
v_fracflag = False
clear_var_flag = False
ibm = True

# %%
simPath = '~/../calaf-group2/Zev_research2/perdigao_simulation_results/';
simPath = '/uufs/chpc.utah.edu/common/home/calaf-group2/Zev_research2/ATTO_sims/';
simPath = '~/../calaf-group2/Zev_research2/';
simPath = '/scratch/general/vast/u0851921/';
simPath = '/scratch/general/vast/u0851921/smooth_hill/';
#simPath = '/scratch/general/vast/u0851921/ATTOv2/ATTO1-2/';

# %%
parentpath=simPath + 'sim' + sim + '/';

file_name = 'ke.txt';
ke = np.loadtxt(parentpath + file_name);

ts = np.linspace(0,len(ke)*wbase,len(ke));
plt.figure(dpi = 100);
plt.plot(ts,ke,'k-')

plt.xlabel('timesteps')
plt.ylabel('MKE')
# Out:
# Text(0, 0.5, 'MKE')

# %%
ipath=simPath + 'sim' + sim + '/output/ta1_field/'
cpath=simPath + 'sim' + sim + '/output/cut_cell/'
opath=simPath + 'sim' + sim + '/output/'

param = np.loadtxt(ipath +'parameters.txt');
nx=param[0]; ny=param[1]; nz=param[2];
lx=param[3]; ly=param[4]; lz=param[5];
dx=param[6]; dy=param[7]; dz=param[8];
nt=param[9]; actLaunch=param[10]; mpiProc=param[11];
Re=param[12]; Ri=param[13]; Pr=param[14]; alpha=param[15];
SGS=param[16]; S_FLAG = param[17]; ibm=param[18];
rot=param[19] 
nzTot=nz
z_shift = 4.5*dz  #IBM 

x= np.linspace(0,nx-1)*dx#[0:nx-1]*dx
y=np.linspace(0,ny-1)*dy
z_uvp=np.linspace(0,nzTot-1)*dz+0.5*dz
z_w=np.linspace(0,nzTot-1)*dz

# %%
if ibm:
    phi = gv.build_phi(opath+ 'phi_functions/',nx,ny,nz,mpiProc)
    intf,iintf = gv.build_intf(phi,dz)
else:
    pass
#     iintf = np.zeros((int(nx),int(ny))
#     intf = np.zeros((int(nx),int(ny))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /scratch/local/u0851921/12584061/ipykernel_2025202/3378900726.py in <cell line: 1>()
#       1 if ibm:
# ----> 2     phi = gv.build_phi(opath+ 'phi_functions/',nx,ny,nz,mpiProc)
#       3     intf,iintf = gv.build_intf(phi,dz)
#       4 else:
#       5     pass
#
# AttributeError: module 'functions.get_var' has no attribute 'build_phi'

# %%
print(dir(gv))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'avgt', 'get_var', 'mpiproc', 'np', 'nt', 'nx', 'ny', 'nzTot', 'path', 'plt', 'sim', 'u', 'uavg_z', 'var']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/u0851921/12584061/ipykernel_2025202/311744476.py in <cell line: 1>()
# ----> 1 importlib.reload(functions.get_var)
#
# NameError: name 'importlib' is not defined
